# %%
import pandas as pd
import numpy as np

X = pd.read_csv ('X_1994.csv')
X = X.drop(["Unnamed: 0"], axis = 1)
display(X)
y = pd.read_csv('y_1994.csv')
y = y.drop(["Unnamed: 0"], axis = 1)
y = y.replace("<=50K", 0)
y = y.replace(">50K", 1)
y = y.values.ravel()
display(y)
# Out:
#        age    fnlwgt  educational-num  ...  race_cat  gender_cat  native-country_cat
# 0       25  226802.0                7  ...         2           1                  38
# 1       38   89814.0                9  ...         4           1                  38
# 2       28  336951.0               12  ...         4           1                  38
# 3       44  160323.0               10  ...         2           1                  38
# 4       34  198693.0                6  ...         4           1                  38
# ...    ...       ...              ...  ...       ...         ...                 ...
# 45217   27  257302.0               12  ...         4           0                  38
# 45218   40  154374.0                9  ...         4           1                  38
# 45219   58  151910.0                9  ...         4           0                  38
# 45220   22  201490.0                9  ...         4           1                  38
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

parameter_space = {
    # 'hidden_layer_sizes': [(10,30,10),(20,)],
    'activation': ['tanh', 'relu', 'logisitc', 'identity'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.0005, .005, .05],
    'learning_rate': ['constant','adaptive'],
}

mlp = MLPClassifier(max_iter = 1000)
grid_search = GridSearchCV(estimator = mlp, param_grid = parameter_space, cv = 5)
grid_search.fit(X_train, y_train)
bestest = grid_search.best_estimator_
preds = bestest.predict_proba(X_test)
print(grid_search.best_params_)
bestest.fit(X_train, y_train)
print("AUC: " + str(roc_auc_score(y_test, preds[:,1])))
feat_importances = pd.Series(bestest.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.title("MLP Feature Importance")

# {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# AUC: 0.7206790486315984
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-de2094596feb> in <module>()
#      17 mlp = MLPClassifier(max_iter = 1000)
#      18 grid_search = GridSearchCV(estimator = mlp, param_grid = parameter_space, cv = 5)
# ---> 19 grid_search.fit(X_train, y_train)
#      20 bestest = grid_search.best_estimator_
#      21 preds = bestest.predict_proba(X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
# ...

# %%
params = {
    
}
gridsearch_params = [
    (activation)
    for activation in ['relu', 'identity']
]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
max_score = 0.0
activations =  ['relu', 'idenity']
scores = []
best_params = None
for activation in gridsearch_params:
    print("Test with activation={}".format(
                             activation,))
    # Update our parameters
    params['activation'] = activation
    # Run 
    boost = MLPClassifier(max_iter = 2000)
    boost.set_params(**params)
    boost.fit(X_train, y_train)
    preds = boost.predict_proba(X_test)
    pscore = roc_auc_score(y_test, preds[:,1])
    scores.append(pscore)
    print ("ROC:" + str(pscore))
    # Update best precision
    if pscore > max_score:
        max_score = pscore
        best_params = activation
print("Best params: {}, score: {}".format(best_params, max_score))
plt.plot(activations, scores)
plt.xlabel("activation")
plt.ylabel("auc score")
plt.subplot()

# Test with activation=tanh
# ROC:0.5217305814239165
# Test with activation=relu
# ROC:0.8188702126418299
# Test with activation=identity
# ROC:0.8323623780065734
# Out:
# Test with activation=relu
# ROC:0.8329195602710375
# Test with activation=identity
# ROC:0.8349045626883134
# Best params: identity, score: 0.8349045626883134
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-096a57524bc7> in <module>()
#      31         best_params = activation
#      32 print("Best params: {}, score: {}".format(best_params, max_score))
# ---> 33 plt.plot(activations, scores)
#      34 plt.xlabel("activation")
#      35 plt.ylabel("auc score")
#
# NameError: name 'plt' is not defined

# %%
print(boost.get_params)
params = {
    'activation' : 'identity' ,# FILL THIS IN
    'solver': 'adam'
}
gridsearch_params = [
    (solver)
    for solver in  ['adam']
]

max_score = 0.0
solvers =  ['adam']
scores = []
best_params = None
for solver in gridsearch_params:
    print("Test with solver={}".format(
                             solver,))
    # Update our parameters
    params['solver'] = solver
    # Run 
    boost = MLPClassifier(max_iter = 2000)
    boost.set_params(**params)
    boost.fit(X_train, y_train)
    preds = boost.predict_proba(X_test)
    pscore = roc_auc_score(y_test, preds[:,1])
    scores.append(pscore)
    print ("ROC:" + str(pscore))
    # Update best precision
    if pscore > max_score:
        max_score = pscore
        best_params = solver
print("Best params: {}, score: {}".format(best_params, max_score))

# sovler: adam
# ROC:0.810779953200729
# Out:
# <bound method BaseEstimator.get_params of MLPClassifier(activation='identity', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=2000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)>
# Test with solver=adam
# ROC:0.7140267890023545
# Best params: adam, score: 0.7140267890023545
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
params = {
    'activation' : 'relu' ,
    'solver': 'adam' ,
    'alpha' : .005
}
gridsearch_params = [
    (alpha)
    for alpha in  [.0001]
]

max_score = 0.0
alphas = [.005]
scores = []
best_params = None
for alpha in gridsearch_params:
    print("Test with alpha={}".format(
                             alpha,))
    # Update our parameters
    params['alpha'] = alpha
    # Run 
    boost = MLPClassifier(max_iter = 2000)
    boost.set_params(**params)
    print(boost.get_params)
    boost.fit(X_train, y_train)
    preds = boost.predict_proba(X_test)
    pscore = roc_auc_score(y_test, preds[:,1])
    scores.append(pscore)
    print ("ROC:" + str(pscore))
    # Update best precision
    if pscore > max_score:
        max_score = pscore
        best_params = alpha
print("Best params: {}, score: {}".format(best_params, max_score))

# Test with alpha=0.005
# <bound method BaseEstimator.get_params of MLPClassifier(activation='relu', alpha=0.005, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=2000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)>
# ROC:0.8136550491978193
# Best params: 0.005, score: 0.8136550491978193
# Out:
# Test with alpha=0.0001
# <bound method BaseEstimator.get_params of MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=2000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)>
# ROC:0.8061813905241619
# Best params: 0.0001, score: 0.8061813905241619

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
params = {
    'activation' : 'identity' ,
    'solver': 'adam' ,
    'alpha' : .0001, 
    'learning_rate' : 'constant',
}
seeds =  list(range(1, 21))
rocSum = 0
for i in seeds: 
  mlp = MLPClassifier(max_iter = 2000, random_state = i)
  mlp.set_params(**params)
  mlp.fit(X_train, y_train)
  preds = mlp.predict_proba(X_test)
  rocScore = roc_auc_score(y_test, preds[:,1])
  print(rocScore)
  rocSum += rocScore
print("Avg: " + str(rocSum/20))
# max iter = 3000
# <bound method BaseEstimator.get_params of MLPClassifier(activation='relu', alpha=0.005, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)>
# AUC: 0.8259611251888289
# AUC: 0.8104974720713884
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.8355380604622188
# 0.8374385620518888
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.694753308048696
# 0.776101869693397
# 0.788351972894407
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.7566160388878254
# 0.7603301490400435
# ...
